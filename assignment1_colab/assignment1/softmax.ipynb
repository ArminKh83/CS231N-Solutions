# %%
# # This mounts your Google Drive to the Colab VM.
# from google.colab import drive
# drive.mount('/content/drive')
# 
# # TODO: Enter the foldername in your Drive where you have saved the unzipped
# # assignment folder, e.g. 'cs231n/assignments/assignment1/'
# FOLDERNAME = None
# assert FOLDERNAME is not None, "[!] Enter the foldername."
# 
# # Now that we've mounted your Drive, this ensures that
# # the Python interpreter of the Colab VM can load
# # python files from within it.
# import sys
# sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# 
# # This downloads the CIFAR-10 dataset to your Drive
# # if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.356850
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 1.141914 analytic: 1.141913, relative error: 6.080357e-08
# numerical: -3.606073 analytic: -3.606073, relative error: 4.914732e-09
# numerical: 1.221078 analytic: 1.221078, relative error: 4.477646e-08
# numerical: -0.231282 analytic: -0.231282, relative error: 3.597488e-07
# numerical: 1.487181 analytic: 1.487181, relative error: 3.154496e-08
# numerical: 2.409100 analytic: 2.409100, relative error: 4.367162e-08
# numerical: 1.600530 analytic: 1.600530, relative error: 6.438388e-09
# numerical: -0.209405 analytic: -0.209405, relative error: 6.270973e-08
# numerical: 0.410962 analytic: 0.410962, relative error: 2.119343e-08
# numerical: 2.711999 analytic: 2.711999, relative error: 2.420193e-08
# numerical: -1.071926 analytic: -1.071926, relative error: 4.475790e-09
# numerical: 1.824017 analytic: 1.824017, relative error: 4.785729e-08
# numerical: 2.494117 analytic: 2.494117, relative error: 1.978547e-09
# numerical: 2.427810 analytic: 2.427809, relative error: 3.106638e-08
# numerical: 2.240871 analytic: 2.240871, relative error: 3.265674e-08
# numerical: -0.187991 analytic: -0.187991, relative error: 1.524101e-07
# numerical: -3.547337 analytic: -3.547337, relative error: 1.862115e-08
# numerical: 1.644213 analytic: 1.644213, relative error: 9.032672e-09
# numerical: -1.156088 analytic: -1.156088, relative error: 1.165676e-08
# numerical: -4.574213 analytic: -4.574213, relative error: 1.009271e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.356850e+00 computed in 0.087667s
# vectorized loss: 2.356850e+00 computed in 0.002942s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = np.geomspace(1e-7, 5e-7, 12)
regularization_strengths = np.geomspace(2.5e3, 5e4, 10)

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
from itertools import product
params = list(product(learning_rates,regularization_strengths))
total_params = len(params)

for i ,(lr,reg) in enumerate(params):
    print(f'{i+1}/{total_params} combinations')
    cur_softmax = Softmax()
    cur_softmax.train(X_train, y_train, lr, reg, num_iters=1000)
    
    
    y_train_pred ,y_val_pred = cur_softmax.predict(X_train) , cur_softmax.predict(X_val)
    training_accuracy, validation_accuracy = np.mean(y_train == y_train_pred) , np.mean(y_val == y_val_pred)
    
    
    results[(lr,reg)] = (training_accuracy, validation_accuracy)

    if validation_accuracy > best_val:
        best_val = validation_accuracy
        best_softmax = cur_softmax
    
    
    
    





# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# 1/120 combinations
# 2/120 combinations
# 3/120 combinations
# 4/120 combinations
# 5/120 combinations
# 6/120 combinations
# 7/120 combinations
# 8/120 combinations
# 9/120 combinations
# 10/120 combinations
# 11/120 combinations
# 12/120 combinations
# 13/120 combinations
# 14/120 combinations
# 15/120 combinations
# 16/120 combinations
# 17/120 combinations
# 18/120 combinations
# 19/120 combinations
# 20/120 combinations
# 21/120 combinations
# 22/120 combinations
# 23/120 combinations
# 24/120 combinations
# 25/120 combinations
# 26/120 combinations
# 27/120 combinations
# 28/120 combinations
# 29/120 combinations
# 30/120 combinations
# 31/120 combinations
# 32/120 combinations
# 33/120 combinations
# 34/120 combinations
# 35/120 combinations
# 36/120 combinations
# 37/120 combinations
# 38/120 combinations
# 39/120 combinations
# 40/120 combinations
# 41/120 combinations
# 42/120 combinations
# 43/120 combinations
# 44/120 combinations
# 45/120 combinations
# 46/120 combinations
# 47/120 combinations
# 48/120 combinations
# 49/120 combinations
# 50/120 combinations
# 51/120 combinations
# 52/120 combinations
# 53/120 combinations
# 54/120 combinations
# 55/120 combinations
# 56/120 combinations
# 57/120 combinations
# 58/120 combinations
# 59/120 combinations
# 60/120 combinations
# 61/120 combinations
# 62/120 combinations
# 63/120 combinations
# 64/120 combinations
# 65/120 combinations
# 66/120 combinations
# 67/120 combinations
# 68/120 combinations
# 69/120 combinations
# 70/120 combinations
# 71/120 combinations
# 72/120 combinations
# 73/120 combinations
# 74/120 combinations
# 75/120 combinations
# 76/120 combinations
# 77/120 combinations
# 78/120 combinations
# 79/120 combinations
# 80/120 combinations
# 81/120 combinations
# 82/120 combinations
# 83/120 combinations
# 84/120 combinations
# 85/120 combinations
# 86/120 combinations
# 87/120 combinations
# 88/120 combinations
# 89/120 combinations
# 90/120 combinations
# 91/120 combinations
# 92/120 combinations
# 93/120 combinations
# 94/120 combinations
# 95/120 combinations
# 96/120 combinations
# 97/120 combinations
# 98/120 combinations
# 99/120 combinations
# 100/120 combinations
# 101/120 combinations
# 102/120 combinations
# 103/120 combinations
# 104/120 combinations
# 105/120 combinations
# 106/120 combinations
# 107/120 combinations
# 108/120 combinations
# 109/120 combinations
# 110/120 combinations
# 111/120 combinations
# 112/120 combinations
# 113/120 combinations
# 114/120 combinations
# 115/120 combinations
# 116/120 combinations
# 117/120 combinations
# 118/120 combinations
# 119/120 combinations
# 120/120 combinations
# lr 1.000000e-07 reg 2.500000e+03 train accuracy: 0.251571 val accuracy: 0.237000
# lr 1.000000e-07 reg 3.487377e+03 train accuracy: 0.261531 val accuracy: 0.292000
# lr 1.000000e-07 reg 4.864719e+03 train accuracy: 0.283898 val accuracy: 0.277000
# lr 1.000000e-07 reg 6.786044e+03 train accuracy: 0.300245 val accuracy: 0.299000
# lr 1.000000e-07 reg 9.466198e+03 train accuracy: 0.324306 val accuracy: 0.321000
# lr 1.000000e-07 reg 1.320488e+04 train accuracy: 0.342469 val accuracy: 0.344000
# lr 1.000000e-07 reg 1.842016e+04 train accuracy: 0.339776 val accuracy: 0.352000
# lr 1.000000e-07 reg 2.569521e+04 train accuracy: 0.327429 val accuracy: 0.345000
# lr 1.000000e-07 reg 3.584356e+04 train accuracy: 0.325122 val accuracy: 0.338000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.307898 val accuracy: 0.325000
# lr 1.157558e-07 reg 2.500000e+03 train accuracy: 0.269735 val accuracy: 0.270000
# lr 1.157558e-07 reg 3.487377e+03 train accuracy: 0.285592 val accuracy: 0.280000
# lr 1.157558e-07 reg 4.864719e+03 train accuracy: 0.303163 val accuracy: 0.320000
# lr 1.157558e-07 reg 6.786044e+03 train accuracy: 0.320776 val accuracy: 0.320000
# lr 1.157558e-07 reg 9.466198e+03 train accuracy: 0.341796 val accuracy: 0.353000
# lr 1.157558e-07 reg 1.320488e+04 train accuracy: 0.343980 val accuracy: 0.351000
# lr 1.157558e-07 reg 1.842016e+04 train accuracy: 0.338633 val accuracy: 0.350000
# lr 1.157558e-07 reg 2.569521e+04 train accuracy: 0.326857 val accuracy: 0.339000
# lr 1.157558e-07 reg 3.584356e+04 train accuracy: 0.319735 val accuracy: 0.338000
# lr 1.157558e-07 reg 5.000000e+04 train accuracy: 0.307224 val accuracy: 0.320000
# lr 1.339940e-07 reg 2.500000e+03 train accuracy: 0.276571 val accuracy: 0.301000
# lr 1.339940e-07 reg 3.487377e+03 train accuracy: 0.294796 val accuracy: 0.310000
# lr 1.339940e-07 reg 4.864719e+03 train accuracy: 0.321061 val accuracy: 0.322000
# lr 1.339940e-07 reg 6.786044e+03 train accuracy: 0.339612 val accuracy: 0.328000
# lr 1.339940e-07 reg 9.466198e+03 train accuracy: 0.346571 val accuracy: 0.361000
# lr 1.339940e-07 reg 1.320488e+04 train accuracy: 0.349367 val accuracy: 0.372000
# lr 1.339940e-07 reg 1.842016e+04 train accuracy: 0.337673 val accuracy: 0.358000
# lr 1.339940e-07 reg 2.569521e+04 train accuracy: 0.327918 val accuracy: 0.340000
# lr 1.339940e-07 reg 3.584356e+04 train accuracy: 0.328265 val accuracy: 0.333000
# lr 1.339940e-07 reg 5.000000e+04 train accuracy: 0.301061 val accuracy: 0.315000
# lr 1.551059e-07 reg 2.500000e+03 train accuracy: 0.300204 val accuracy: 0.302000
# lr 1.551059e-07 reg 3.487377e+03 train accuracy: 0.313286 val accuracy: 0.320000
# lr 1.551059e-07 reg 4.864719e+03 train accuracy: 0.330510 val accuracy: 0.315000
# lr 1.551059e-07 reg 6.786044e+03 train accuracy: 0.353224 val accuracy: 0.366000
# lr 1.551059e-07 reg 9.466198e+03 train accuracy: 0.357653 val accuracy: 0.369000
# lr 1.551059e-07 reg 1.320488e+04 train accuracy: 0.346184 val accuracy: 0.362000
# lr 1.551059e-07 reg 1.842016e+04 train accuracy: 0.338020 val accuracy: 0.357000
# lr 1.551059e-07 reg 2.569521e+04 train accuracy: 0.329224 val accuracy: 0.341000
# lr 1.551059e-07 reg 3.584356e+04 train accuracy: 0.314694 val accuracy: 0.331000
# lr 1.551059e-07 reg 5.000000e+04 train accuracy: 0.299755 val accuracy: 0.318000
# lr 1.795440e-07 reg 2.500000e+03 train accuracy: 0.311163 val accuracy: 0.292000
# lr 1.795440e-07 reg 3.487377e+03 train accuracy: 0.330980 val accuracy: 0.348000
# lr 1.795440e-07 reg 4.864719e+03 train accuracy: 0.346612 val accuracy: 0.355000
# lr 1.795440e-07 reg 6.786044e+03 train accuracy: 0.359653 val accuracy: 0.356000
# lr 1.795440e-07 reg 9.466198e+03 train accuracy: 0.359347 val accuracy: 0.370000
# lr 1.795440e-07 reg 1.320488e+04 train accuracy: 0.350429 val accuracy: 0.359000
# lr 1.795440e-07 reg 1.842016e+04 train accuracy: 0.336959 val accuracy: 0.352000
# lr 1.795440e-07 reg 2.569521e+04 train accuracy: 0.324714 val accuracy: 0.339000
# lr 1.795440e-07 reg 3.584356e+04 train accuracy: 0.322939 val accuracy: 0.342000
# lr 1.795440e-07 reg 5.000000e+04 train accuracy: 0.313469 val accuracy: 0.332000
# lr 2.078326e-07 reg 2.500000e+03 train accuracy: 0.330714 val accuracy: 0.342000
# lr 2.078326e-07 reg 3.487377e+03 train accuracy: 0.342694 val accuracy: 0.350000
# lr 2.078326e-07 reg 4.864719e+03 train accuracy: 0.355612 val accuracy: 0.355000
# lr 2.078326e-07 reg 6.786044e+03 train accuracy: 0.364000 val accuracy: 0.371000
# lr 2.078326e-07 reg 9.466198e+03 train accuracy: 0.358878 val accuracy: 0.374000
# lr 2.078326e-07 reg 1.320488e+04 train accuracy: 0.347367 val accuracy: 0.365000
# lr 2.078326e-07 reg 1.842016e+04 train accuracy: 0.337980 val accuracy: 0.347000
# lr 2.078326e-07 reg 2.569521e+04 train accuracy: 0.329429 val accuracy: 0.348000
# lr 2.078326e-07 reg 3.584356e+04 train accuracy: 0.317735 val accuracy: 0.339000
# lr 2.078326e-07 reg 5.000000e+04 train accuracy: 0.303959 val accuracy: 0.304000
# lr 2.405783e-07 reg 2.500000e+03 train accuracy: 0.341061 val accuracy: 0.355000
# lr 2.405783e-07 reg 3.487377e+03 train accuracy: 0.354776 val accuracy: 0.354000
# lr 2.405783e-07 reg 4.864719e+03 train accuracy: 0.368245 val accuracy: 0.375000
# lr 2.405783e-07 reg 6.786044e+03 train accuracy: 0.363959 val accuracy: 0.375000
# lr 2.405783e-07 reg 9.466198e+03 train accuracy: 0.356714 val accuracy: 0.367000
# lr 2.405783e-07 reg 1.320488e+04 train accuracy: 0.347429 val accuracy: 0.362000
# lr 2.405783e-07 reg 1.842016e+04 train accuracy: 0.335510 val accuracy: 0.351000
# lr 2.405783e-07 reg 2.569521e+04 train accuracy: 0.321122 val accuracy: 0.325000
# lr 2.405783e-07 reg 3.584356e+04 train accuracy: 0.317449 val accuracy: 0.330000
# lr 2.405783e-07 reg 5.000000e+04 train accuracy: 0.306224 val accuracy: 0.316000
# lr 2.784833e-07 reg 2.500000e+03 train accuracy: 0.351816 val accuracy: 0.349000
# lr 2.784833e-07 reg 3.487377e+03 train accuracy: 0.365898 val accuracy: 0.355000
# lr 2.784833e-07 reg 4.864719e+03 train accuracy: 0.367918 val accuracy: 0.385000
# lr 2.784833e-07 reg 6.786044e+03 train accuracy: 0.365469 val accuracy: 0.383000
# lr 2.784833e-07 reg 9.466198e+03 train accuracy: 0.358061 val accuracy: 0.366000
# lr 2.784833e-07 reg 1.320488e+04 train accuracy: 0.348592 val accuracy: 0.366000
# lr 2.784833e-07 reg 1.842016e+04 train accuracy: 0.344878 val accuracy: 0.359000
# lr 2.784833e-07 reg 2.569521e+04 train accuracy: 0.320184 val accuracy: 0.338000
# lr 2.784833e-07 reg 3.584356e+04 train accuracy: 0.317633 val accuracy: 0.330000
# lr 2.784833e-07 reg 5.000000e+04 train accuracy: 0.302816 val accuracy: 0.320000
# lr 3.223605e-07 reg 2.500000e+03 train accuracy: 0.364918 val accuracy: 0.374000
# lr 3.223605e-07 reg 3.487377e+03 train accuracy: 0.372490 val accuracy: 0.392000
# lr 3.223605e-07 reg 4.864719e+03 train accuracy: 0.372755 val accuracy: 0.392000
# lr 3.223605e-07 reg 6.786044e+03 train accuracy: 0.366449 val accuracy: 0.385000
# lr 3.223605e-07 reg 9.466198e+03 train accuracy: 0.351551 val accuracy: 0.367000
# lr 3.223605e-07 reg 1.320488e+04 train accuracy: 0.352857 val accuracy: 0.372000
# lr 3.223605e-07 reg 1.842016e+04 train accuracy: 0.337714 val accuracy: 0.351000
# lr 3.223605e-07 reg 2.569521e+04 train accuracy: 0.326061 val accuracy: 0.326000
# lr 3.223605e-07 reg 3.584356e+04 train accuracy: 0.324102 val accuracy: 0.333000
# lr 3.223605e-07 reg 5.000000e+04 train accuracy: 0.318102 val accuracy: 0.323000
# lr 3.731509e-07 reg 2.500000e+03 train accuracy: 0.372306 val accuracy: 0.367000
# lr 3.731509e-07 reg 3.487377e+03 train accuracy: 0.380102 val accuracy: 0.393000
# lr 3.731509e-07 reg 4.864719e+03 train accuracy: 0.368714 val accuracy: 0.374000
# lr 3.731509e-07 reg 6.786044e+03 train accuracy: 0.362980 val accuracy: 0.375000
# lr 3.731509e-07 reg 9.466198e+03 train accuracy: 0.353245 val accuracy: 0.371000
# lr 3.731509e-07 reg 1.320488e+04 train accuracy: 0.343673 val accuracy: 0.373000
# lr 3.731509e-07 reg 1.842016e+04 train accuracy: 0.340082 val accuracy: 0.341000
# lr 3.731509e-07 reg 2.569521e+04 train accuracy: 0.330449 val accuracy: 0.337000
# lr 3.731509e-07 reg 3.584356e+04 train accuracy: 0.315673 val accuracy: 0.335000
# lr 3.731509e-07 reg 5.000000e+04 train accuracy: 0.304939 val accuracy: 0.325000
# lr 4.319438e-07 reg 2.500000e+03 train accuracy: 0.378939 val accuracy: 0.385000
# lr 4.319438e-07 reg 3.487377e+03 train accuracy: 0.380082 val accuracy: 0.403000
# lr 4.319438e-07 reg 4.864719e+03 train accuracy: 0.374224 val accuracy: 0.389000
# lr 4.319438e-07 reg 6.786044e+03 train accuracy: 0.367898 val accuracy: 0.371000
# lr 4.319438e-07 reg 9.466198e+03 train accuracy: 0.354959 val accuracy: 0.361000
# lr 4.319438e-07 reg 1.320488e+04 train accuracy: 0.347551 val accuracy: 0.362000
# lr 4.319438e-07 reg 1.842016e+04 train accuracy: 0.335224 val accuracy: 0.346000
# lr 4.319438e-07 reg 2.569521e+04 train accuracy: 0.322327 val accuracy: 0.341000
# lr 4.319438e-07 reg 3.584356e+04 train accuracy: 0.319102 val accuracy: 0.329000
# lr 4.319438e-07 reg 5.000000e+04 train accuracy: 0.306816 val accuracy: 0.314000
# lr 5.000000e-07 reg 2.500000e+03 train accuracy: 0.379592 val accuracy: 0.388000
# lr 5.000000e-07 reg 3.487377e+03 train accuracy: 0.380102 val accuracy: 0.385000
# lr 5.000000e-07 reg 4.864719e+03 train accuracy: 0.373122 val accuracy: 0.385000
# lr 5.000000e-07 reg 6.786044e+03 train accuracy: 0.363857 val accuracy: 0.376000
# lr 5.000000e-07 reg 9.466198e+03 train accuracy: 0.353612 val accuracy: 0.369000
# lr 5.000000e-07 reg 1.320488e+04 train accuracy: 0.345816 val accuracy: 0.352000
# lr 5.000000e-07 reg 1.842016e+04 train accuracy: 0.338551 val accuracy: 0.352000
# lr 5.000000e-07 reg 2.569521e+04 train accuracy: 0.327163 val accuracy: 0.348000
# lr 5.000000e-07 reg 3.584356e+04 train accuracy: 0.309306 val accuracy: 0.326000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.299571 val accuracy: 0.312000
# best validation accuracy achieved during cross-validation: 0.403000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.379000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
